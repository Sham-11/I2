# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical

# Load CIFAR-10
data = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = data.load_data()
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# Normalize
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# Data Augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# %%
# Custom CNN Model
def build_strong_cnn():
    model = models.Sequential([
        layers.Conv2D(64, 3, padding='same', activation='relu', input_shape=(32, 32, 3)),
        layers.BatchNormalization(),
        layers.Conv2D(64, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Dropout(0.3),

        layers.Conv2D(128, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(128, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Dropout(0.4),

        layers.Conv2D(256, 3, padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(),
        layers.Dropout(0.4),

        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Train Custom CNN
cnn_model = build_strong_cnn()
train_flow = datagen.flow(x_train, y_train_cat, batch_size=64)
steps = len(x_train) // 64
cnn_model.fit(train_flow,
              steps_per_epoch=steps,
              epochs=50,
              validation_data=(x_test, y_test_cat),
              callbacks=[EarlyStopping(patience=7, restore_best_weights=True)])
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 49s 49ms/step - accuracy: 0.2651 - loss: 2.1532 - val_accuracy: 0.4724 - val_loss: 1.4704
# Epoch 2/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3906 - loss: 1.5699
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3906 - loss: 1.5699 - val_accuracy: 0.4709 - val_loss: 1.4576
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4310 - loss: 1.5649 - val_accuracy: 0.5443 - val_loss: 1.3267
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4688 - loss: 1.4598 - val_accuracy: 0.5416 - val_loss: 1.3229
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.5150 - loss: 1.3499 - val_accuracy: 0.4093 - val_loss: 1.9003
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4844 - loss: 1.4037 - val_accuracy: 0.4013 - val_loss: 1.9077
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.5711 - loss: 1.2109 - val_accuracy: 0.6057 - val_loss: 1.1407
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5625 - loss: 1.1708 - val_accuracy: 0.6084 - val_loss: 1.1293
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.6148 - loss: 1.1177 - val_accuracy: 0.6840 - val_loss: 0.9180
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6562 - loss: 0.9989 - val_accuracy: 0.6875 - val_loss: 0.9127
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.6415 - loss: 1.0455 - val_accuracy: 0.6996 - val_loss: 0.8832
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6406 - loss: 0.9857 - val_accuracy: 0.7012 - val_loss: 0.8778
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.6640 - loss: 0.9816 - val_accuracy: 0.7006 - val_loss: 0.9320
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.9440 - val_accuracy: 0.6958 - val_loss: 0.9809
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.6796 - loss: 0.9495 - val_accuracy: 0.7385 - val_loss: 0.7678
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5938 - loss: 1.1314 - val_accuracy: 0.7404 - val_loss: 0.7484
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.6963 - loss: 0.8961 - val_accuracy: 0.7328 - val_loss: 0.8002
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.7337 - val_accuracy: 0.7354 - val_loss: 0.7916
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.7056 - loss: 0.8741 - val_accuracy: 0.7410 - val_loss: 0.8009
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6719 - loss: 0.9887 - val_accuracy: 0.7451 - val_loss: 0.7892
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 39ms/step - accuracy: 0.7190 - loss: 0.8344 - val_accuracy: 0.7457 - val_loss: 0.8261
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6719 - loss: 0.8865 - val_accuracy: 0.7415 - val_loss: 0.8412
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7246 - loss: 0.8107 - val_accuracy: 0.7617 - val_loss: 0.7462
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.7158 - val_accuracy: 0.7615 - val_loss: 0.7435
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.7406 - loss: 0.7857 - val_accuracy: 0.7736 - val_loss: 0.6845
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.7843 - val_accuracy: 0.7704 - val_loss: 0.6920
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.7472 - loss: 0.7585 - val_accuracy: 0.7381 - val_loss: 0.8748
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7969 - loss: 0.6471 - val_accuracy: 0.7414 - val_loss: 0.8612
# Epoch 29/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7544 - loss: 0.7326 - val_accuracy: 0.7823 - val_loss: 0.6823
# Epoch 30/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8281 - loss: 0.7274 - val_accuracy: 0.7819 - val_loss: 0.6844
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 41ms/step - accuracy: 0.7599 - loss: 0.7175 - val_accuracy: 0.7427 - val_loss: 0.8540
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7344 - loss: 0.8041 - val_accuracy: 0.7407 - val_loss: 0.8514
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.7677 - loss: 0.6976 - val_accuracy: 0.7922 - val_loss: 0.6539
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.4176 - val_accuracy: 0.7853 - val_loss: 0.6854
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7708 - loss: 0.6899 - val_accuracy: 0.8050 - val_loss: 0.5962
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.7468 - val_accuracy: 0.8056 - val_loss: 0.5937
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.7808 - loss: 0.6642 - val_accuracy: 0.7891 - val_loss: 0.6662
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9062 - loss: 0.4433 - val_accuracy: 0.7898 - val_loss: 0.6593
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7822 - loss: 0.6567 - val_accuracy: 0.7525 - val_loss: 0.8826
# Epoch 40/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7812 - loss: 0.8993 - val_accuracy: 0.7547 - val_loss: 0.8676
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 40ms/step - accuracy: 0.7859 - loss: 0.6467 - val_accuracy: 0.7798 - val_loss: 0.7150
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7188 - loss: 0.6921 - val_accuracy: 0.7762 - val_loss: 0.7296
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.7890 - loss: 0.6233 - val_accuracy: 0.8343 - val_loss: 0.5057
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.5829 - val_accuracy: 0.8338 - val_loss: 0.5047
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.7962 - loss: 0.6090 - val_accuracy: 0.8280 - val_loss: 0.5439
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8906 - loss: 0.3913 - val_accuracy: 0.8280 - val_loss: 0.5434
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 40ms/step - accuracy: 0.8023 - loss: 0.5946 - val_accuracy: 0.8086 - val_loss: 0.5982
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.6687 - val_accuracy: 0.8100 - val_loss: 0.5932
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 40ms/step - accuracy: 0.8040 - loss: 0.5829 - val_accuracy: 0.8442 - val_loss: 0.4833
# Epoch 50/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7969 - loss: 0.6502 - val_accuracy: 0.8451 - val_loss: 0.4794

# %%
cnn_acc = cnn_model.evaluate(x_test, y_test_cat, verbose=0)[1]
print(f"Custom CNN Test Accuracy: {cnn_acc * 100:.2f}%")
# Out:
# Custom CNN Test Accuracy: 84.51%

# %%
# Transfer Learning with VGG16

def build_finetuned_vgg():
    base_model = VGG16(include_top=False, weights='imagenet', input_shape=(32, 32, 3))
    for layer in base_model.layers[-4:]:
        layer.trainable = True

    model = models.Sequential([
        base_model,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(10, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                  loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Train VGG16 model
vgg_model = build_finetuned_vgg()
vgg_model.fit(train_flow,
              steps_per_epoch=steps,
              epochs=50,
              validation_data=(x_test, y_test_cat),
              callbacks=[EarlyStopping(patience=7, restore_best_weights=True)])
# Out:
# Epoch 1/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 60s 64ms/step - accuracy: 0.5014 - loss: 1.4271 - val_accuracy: 0.7579 - val_loss: 0.7306
# Epoch 2/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7031 - loss: 0.8554 - val_accuracy: 0.7620 - val_loss: 0.7219
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.7659 - loss: 0.7225 - val_accuracy: 0.8104 - val_loss: 0.5688
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7031 - loss: 0.8890 - val_accuracy: 0.8148 - val_loss: 0.5631
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 80s 56ms/step - accuracy: 0.8054 - loss: 0.5956 - val_accuracy: 0.8286 - val_loss: 0.5085
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8750 - loss: 0.4579 - val_accuracy: 0.8280 - val_loss: 0.5111
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 79s 56ms/step - accuracy: 0.8327 - loss: 0.5056 - val_accuracy: 0.8375 - val_loss: 0.5005
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7656 - loss: 0.6160 - val_accuracy: 0.8416 - val_loss: 0.4868
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 79s 56ms/step - accuracy: 0.8498 - loss: 0.4524 - val_accuracy: 0.8430 - val_loss: 0.4722
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7969 - loss: 0.5002 - val_accuracy: 0.8427 - val_loss: 0.4734
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.8680 - loss: 0.4040 - val_accuracy: 0.8567 - val_loss: 0.4344
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8281 - loss: 0.4173 - val_accuracy: 0.8566 - val_loss: 0.4372
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - accuracy: 0.8806 - loss: 0.3630 - val_accuracy: 0.8624 - val_loss: 0.4187
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8906 - loss: 0.3092 - val_accuracy: 0.8640 - val_loss: 0.4068
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 56ms/step - accuracy: 0.8903 - loss: 0.3287 - val_accuracy: 0.8485 - val_loss: 0.4726
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8750 - loss: 0.4166 - val_accuracy: 0.8552 - val_loss: 0.4553
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9019 - loss: 0.2992 - val_accuracy: 0.8773 - val_loss: 0.3973
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8906 - loss: 0.3621 - val_accuracy: 0.8768 - val_loss: 0.4007
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9061 - loss: 0.2783 - val_accuracy: 0.8703 - val_loss: 0.4357
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8750 - loss: 0.3738 - val_accuracy: 0.8715 - val_loss: 0.4304
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9152 - loss: 0.2536 - val_accuracy: 0.8733 - val_loss: 0.4236
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8594 - loss: 0.3408 - val_accuracy: 0.8720 - val_loss: 0.4301
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9212 - loss: 0.2333 - val_accuracy: 0.8659 - val_loss: 0.4431
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9062 - loss: 0.2473 - val_accuracy: 0.8646 - val_loss: 0.4473

# %%
vgg_acc = vgg_model.evaluate(x_test, y_test_cat, verbose=0)[1]
print(f"VGG16 Transfer Learning Test Accuracy: {vgg_acc * 100:.2f}%")
# Out:
# VGG16 Transfer Learning Test Accuracy: 87.73%

# %% [markdown]
# |  **Aspect**            |  **Custom CNN**                               |  **VGG16 (Transfer Learning)**                      |
# | ------------------------ | ----------------------------------------------- | ----------------------------------------------------- |
# | **Model Type**           | CNN built from scratch                          | Pre-trained model fine-tuned on CIFAR-10              |
# | **Architecture**         | \~9–12 layers (Conv, Pooling, Dense)            | 16 layers (13 Conv + 3 Dense), pretrained on ImageNet |
# | **Pretraining Used?**    |  No                                            |  Yes (ImageNet)                                      |
# | **Trainable Parameters** |  Fewer (Lightweight model)                    |  More (Heavy model with millions of parameters)     |
# | **Training Time**        | Fast                                          |  Slower due to model size                            |
# | **Feature Learning**     | Learns everything from scratch                  | Uses high-quality pre-trained visual features         |
# | **Generalization Power** | Moderate (depends on regularization techniques) | High (benefits from pretrained filters)               |
# | **Accuracy Achieved**    | **84.51%**                                      | **87.73%**                                            |
# | **Overfitting Risk**     | Medium                                          | Lower (due to good base features)                     |

# %% [markdown]
# VGG16 outperformed the custom CNN because it uses pretrained features from ImageNet, allowing it to recognize patterns more effectively without learning from scratch. Its deeper architecture captures more complex features, and fine-tuning only the top layers helps it adapt well to CIFAR-10 with less overfitting. In contrast, the custom CNN, being shallower and untrained, had to learn all features from scratch, limiting its performance.
