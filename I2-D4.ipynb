# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load MNIST Dataset
(x_train, y_train), (x_test, y_test)=tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
#Normalize the Dataset
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
#Build the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),        # Flatten 28x28 to 784
    layers.Dense(128, activation='relu'),        # Hidden layer with 128 neurons
    layers.Dense(64, activation='relu'),         # HIdden layer with 64 neurons
    layers.Dense(10, activation='softmax')       # Output layer for 10 classes
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#Train the model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.8671 - loss: 0.4463 - val_accuracy: 0.9665 - val_loss: 0.1110
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9659 - loss: 0.1105 - val_accuracy: 0.9655 - val_loss: 0.1112
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9770 - loss: 0.0744 - val_accuracy: 0.9770 - val_loss: 0.0810
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9839 - loss: 0.0508 - val_accuracy: 0.9752 - val_loss: 0.0777
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9869 - loss: 0.0407 - val_accuracy: 0.9773 - val_loss: 0.0842
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9888 - loss: 0.0342 - val_accuracy: 0.9775 - val_loss: 0.0858
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9911 - loss: 0.0272 - val_accuracy: 0.9750 - val_loss: 0.0982
# Epoch 8/10
# ...

# %%
 #Plot training & validation accuracy and loss
plt.figure(figsize=(12, 5))

# Accuracy Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Loss: {test_loss:.6f}")
print(f"Accuracy: {test_acc:.6f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9747 - loss: 0.1056
# Loss: 0.086999
# Accuracy: 0.978500

# %% [markdown]
# If number of hidden layers increased

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),    # Third hidden layer
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Loss: {test_loss:.6f}")
print(f"Test Accuracy: {test_acc:.6f}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8608 - loss: 0.4756 - val_accuracy: 0.9653 - val_loss: 0.1104
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9630 - loss: 0.1213 - val_accuracy: 0.9737 - val_loss: 0.0914
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9764 - loss: 0.0779 - val_accuracy: 0.9737 - val_loss: 0.0902
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9823 - loss: 0.0553 - val_accuracy: 0.9757 - val_loss: 0.0814
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9873 - loss: 0.0425 - val_accuracy: 0.9807 - val_loss: 0.0672
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9892 - loss: 0.0347 - val_accuracy: 0.9755 - val_loss: 0.0791
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9898 - loss: 0.0321 - val_accuracy: 0.9805 - val_loss: 0.0721
# Epoch 8/10
# ...

# %% [markdown]
# Therefore, increasing the hidden layers would decrease the accuracy and increase the loss. (Number of Hidden Layers is indirectly proportional to Accuracy and directly propotional to Loss)

# %% [markdown]
# If number of neurons increased:

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(256, activation='relu'),   # Increased neurons
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Loss: {test_loss:.6f}")
print(f"Test Accuracy: {test_acc:.6f}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 14s 8ms/step - accuracy: 0.8868 - loss: 0.3816 - val_accuracy: 0.9723 - val_loss: 0.0951
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.9699 - loss: 0.0952 - val_accuracy: 0.9753 - val_loss: 0.0827
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9823 - loss: 0.0566 - val_accuracy: 0.9715 - val_loss: 0.0946
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9868 - loss: 0.0428 - val_accuracy: 0.9755 - val_loss: 0.0874
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9888 - loss: 0.0318 - val_accuracy: 0.9763 - val_loss: 0.0914
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9916 - loss: 0.0247 - val_accuracy: 0.9752 - val_loss: 0.0917
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9936 - loss: 0.0199 - val_accuracy: 0.9767 - val_loss: 0.0912
# Epoch 8/10
# ...

# %% [markdown]
# From the previous model evaluation (Test Loss: 0.115026, Test Accuracy: 0.972300), on increasing neurons, accuracy increased.

# %% [markdown]
# Different Activation Function:

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='tanh'),   # Used tanh instead of relu
    layers.Dense(64, activation='tanh'),
    layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_split=0.1)

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest Loss: {test_loss:.6f}")
print(f"Test Accuracy: {test_acc:.6f}")
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8750 - loss: 0.4381 - val_accuracy: 0.9560 - val_loss: 0.1441
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9578 - loss: 0.1392 - val_accuracy: 0.9725 - val_loss: 0.0938
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9740 - loss: 0.0869 - val_accuracy: 0.9728 - val_loss: 0.0898
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9808 - loss: 0.0597 - val_accuracy: 0.9752 - val_loss: 0.0837
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9862 - loss: 0.0449 - val_accuracy: 0.9803 - val_loss: 0.0716
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9888 - loss: 0.0373 - val_accuracy: 0.9783 - val_loss: 0.0788
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9923 - loss: 0.0269 - val_accuracy: 0.9720 - val_loss: 0.0955
# Epoch 8/10
# ...

# %% [markdown]
# From the very first model evaluation (Loss: 0.086999, Accuracy: 0.978500), using tanh activation function instead of relu decreased the accuracy.
